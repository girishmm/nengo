# %% [markdown]
# # NEF summary
#
# The Neural Engineering Framework (NEF)
# is one set of theoretical methods that are used in
# Nengo for constructing neural models.
# The NEF is based on [Eliasmith & Anderson's (2003) book](
# https://mitpress.mit.edu/books/neural-engineering) from MIT Press.
# This notebook introduces the three main principles
# discussed in that book and implemented in Nengo.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

import nengo
from nengo.dists import Uniform
from nengo.processes import WhiteSignal
from nengo.utils.ensemble import tuning_curves
from nengo.utils.ipython import hide_input
from nengo.utils.matplotlib import rasterplot


def aligned(n_neurons, radius=0.9):
    intercepts = np.linspace(-radius, radius, n_neurons)
    encoders = np.tile([[1], [-1]], (n_neurons // 2, 1))
    intercepts *= encoders[:, 0]
    return intercepts, encoders


hide_input()
# Out:
#         <a id="1129343551" href="javascript:toggle_input_1129343551()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1129343551;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1129343551 = document.getElementById("1129343551");
#                 var cell = link_1129343551;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1129343551;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1129343551 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1129343551 = cell.previousElementSibling;
#                 }
#                 input_1129343551.style.display = "none"; // hide
#
#                 toggle_input_1129343551 = function() {
#                     if (input_1129343551.style.display == "none") {
#                         input_1129343551.style.display = ""; // show
#                         link_1129343551.innerHTML = "Hide Input";
#                     } else {
#                         input_1129343551.style.display = "none"; // hide
#                         link_1129343551.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1129343551 = $("a[id='1129343551']");
#                 var cell_1129343551 = link_1129343551.parents("div.cell:first");
#                 if (cell_1129343551.length == 0) {
#                     cell_1129343551 = link_1129343551.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1129343551 = cell_1129343551.children("div.input");
#                 if (input_1129343551.length == 0) {
#                     input_1129343551 = cell_1129343551.prev("div.nbinput");
#                 }
#                 input_1129343551.hide();
#
#                 toggle_input_1129343551 = function() {
#                     if (input_1129343551.is(':hidden')) {
#                         input_1129343551.slideDown();
#                         link_1129343551[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1129343551.slideUp();
#                         link_1129343551[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 1: Representation
#
# ### Encoding
#
# Neural populations represent time-varying signals
# through their spiking responses.
# A signal is a vector of real numbers of arbitrary length.
# This example is a 1D signal going from -1 to 1 in 1 second.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1.0)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], lw=2)
plt.title("Input signal")
plt.xlabel("Time (s)")
plt.xlim(0, 1);
hide_input()
# Out:
#         <a id="1964515048" href="javascript:toggle_input_1964515048()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1964515048;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1964515048 = document.getElementById("1964515048");
#                 var cell = link_1964515048;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1964515048;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1964515048 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1964515048 = cell.previousElementSibling;
#                 }
#                 input_1964515048.style.display = "none"; // hide
#
#                 toggle_input_1964515048 = function() {
#                     if (input_1964515048.style.display == "none") {
#                         input_1964515048.style.display = ""; // show
#                         link_1964515048.innerHTML = "Hide Input";
#                     } else {
#                         input_1964515048.style.display = "none"; // hide
#                         link_1964515048.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1964515048 = $("a[id='1964515048']");
#                 var cell_1964515048 = link_1964515048.parents("div.cell:first");
#                 if (cell_1964515048.length == 0) {
#                     cell_1964515048 = link_1964515048.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1964515048 = cell_1964515048.children("div.input");
#                 if (input_1964515048.length == 0) {
#                     input_1964515048 = cell_1964515048.prev("div.nbinput");
#                 }
#                 input_1964515048.hide();
#
#                 toggle_input_1964515048 = function() {
#                     if (input_1964515048.is(':hidden')) {
#                         input_1964515048.slideDown();
#                         link_1964515048[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1964515048.slideUp();
#                         link_1964515048[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# These signals drive neural populations
# based on each neuron's *tuning curve*
# (which is similar to the current-frequency curve,
# if you're familiar with that).
#
# The tuning curve describes how much
# a particular neuron will fire as a function of the input signal.

# %%
intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
with model:
    A = nengo.Ensemble(
        8,
        dimensions=1,
        intercepts=intercepts,
        max_rates=Uniform(80, 100),
        encoders=encoders)

# %%
with nengo.Simulator(model) as sim:
    eval_points, activities = tuning_curves(A, sim)

plt.figure()
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)");
hide_input()
# Out:
#         <a id="2048306533" href="javascript:toggle_input_2048306533()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_2048306533;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_2048306533 = document.getElementById("2048306533");
#                 var cell = link_2048306533;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_2048306533;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_2048306533 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_2048306533 = cell.previousElementSibling;
#                 }
#                 input_2048306533.style.display = "none"; // hide
#
#                 toggle_input_2048306533 = function() {
#                     if (input_2048306533.style.display == "none") {
#                         input_2048306533.style.display = ""; // show
#                         link_2048306533.innerHTML = "Hide Input";
#                     } else {
#                         input_2048306533.style.display = "none"; // hide
#                         link_2048306533.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_2048306533 = $("a[id='2048306533']");
#                 var cell_2048306533 = link_2048306533.parents("div.cell:first");
#                 if (cell_2048306533.length == 0) {
#                     cell_2048306533 = link_2048306533.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_2048306533 = cell_2048306533.children("div.input");
#                 if (input_2048306533.length == 0) {
#                     input_2048306533 = cell_2048306533.prev("div.nbinput");
#                 }
#                 input_2048306533.hide();
#
#                 toggle_input_2048306533 = function() {
#                     if (input_2048306533.is(':hidden')) {
#                         input_2048306533.slideDown();
#                         link_2048306533[0].innerHTML = "Hide Input";
#                     } else {
#                         input_2048306533.slideUp();
#                         link_2048306533[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# We can drive these neurons with our input signal
# and observe their spiking activity over time.

# %%
with model:
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
ax = plt.subplot(1, 1, 1)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
ax.set_xlim(0, 1)
ax.set_ylabel('Neuron')
ax.set_xlabel('Time (s)');
hide_input()
# Out:
#         <a id="599726972" href="javascript:toggle_input_599726972()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_599726972;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_599726972 = document.getElementById("599726972");
#                 var cell = link_599726972;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_599726972;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_599726972 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_599726972 = cell.previousElementSibling;
#                 }
#                 input_599726972.style.display = "none"; // hide
#
#                 toggle_input_599726972 = function() {
#                     if (input_599726972.style.display == "none") {
#                         input_599726972.style.display = ""; // show
#                         link_599726972.innerHTML = "Hide Input";
#                     } else {
#                         input_599726972.style.display = "none"; // hide
#                         link_599726972.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_599726972 = $("a[id='599726972']");
#                 var cell_599726972 = link_599726972.parents("div.cell:first");
#                 if (cell_599726972.length == 0) {
#                     cell_599726972 = link_599726972.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_599726972 = cell_599726972.children("div.input");
#                 if (input_599726972.length == 0) {
#                     input_599726972 = cell_599726972.prev("div.nbinput");
#                 }
#                 input_599726972.hide();
#
#                 toggle_input_599726972 = function() {
#                     if (input_599726972.is(':hidden')) {
#                         input_599726972.slideDown();
#                         link_599726972[0].innerHTML = "Hide Input";
#                     } else {
#                         input_599726972.slideUp();
#                         link_599726972[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ### Decoding
#
# We can estimate the input signal
# originally encoded by decoding the pattern of spikes.
# To do this, we first filter the spike train
# with a temporal filter that accounts for
# postsynaptic current (PSC) activity.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
    A = nengo.Ensemble(8, dimensions=1,
                       intercepts=intercepts,
                       max_rates=Uniform(80, 100),
                       encoders=encoders)
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

scale = 180
plt.figure()
for i in range(A.n_neurons):
    plt.plot(sim.trange(), sim.data[A_spikes][:, i] - i * scale)
plt.xlim(0, 1)
plt.ylim(scale * (-A.n_neurons + 1), scale)
plt.ylabel("Neuron")
plt.yticks(
    np.arange(scale / 1.8, (-A.n_neurons + 1) * scale, -scale),
    np.arange(A.n_neurons))
hide_input()
# Out:
#         <a id="1548659407" href="javascript:toggle_input_1548659407()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1548659407;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1548659407 = document.getElementById("1548659407");
#                 var cell = link_1548659407;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1548659407;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1548659407 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1548659407 = cell.previousElementSibling;
#                 }
#                 input_1548659407.style.display = "none"; // hide
#
#                 toggle_input_1548659407 = function() {
#                     if (input_1548659407.style.display == "none") {
#                         input_1548659407.style.display = ""; // show
#                         link_1548659407.innerHTML = "Hide Input";
#                     } else {
#                         input_1548659407.style.display = "none"; // hide
#                         link_1548659407.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1548659407 = $("a[id='1548659407']");
#                 var cell_1548659407 = link_1548659407.parents("div.cell:first");
#                 if (cell_1548659407.length == 0) {
#                     cell_1548659407 = link_1548659407.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1548659407 = cell_1548659407.children("div.input");
#                 if (input_1548659407.length == 0) {
#                     input_1548659407 = cell_1548659407.prev("div.nbinput");
#                 }
#                 input_1548659407.hide();
#
#                 toggle_input_1548659407 = function() {
#                     if (input_1548659407.is(':hidden')) {
#                         input_1548659407.slideDown();
#                         link_1548659407[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1548659407.slideUp();
#                         link_1548659407[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Then we mulitply those filtered spike trains
# with decoding weights and sum them together
# to give an estimate of the input based on the spikes.
#
# The decoding weights are determined
# by minimizing the squared difference
# between the decoded estimate and the actual input signal.

# %%
with model:
    A_probe = nengo.Probe(A, synapse=0.01)  # 10ms PSC filter

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded estimate")
plt.legend(loc="best")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="769216033" href="javascript:toggle_input_769216033()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_769216033;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_769216033 = document.getElementById("769216033");
#                 var cell = link_769216033;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_769216033;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_769216033 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_769216033 = cell.previousElementSibling;
#                 }
#                 input_769216033.style.display = "none"; // hide
#
#                 toggle_input_769216033 = function() {
#                     if (input_769216033.style.display == "none") {
#                         input_769216033.style.display = ""; // show
#                         link_769216033.innerHTML = "Hide Input";
#                     } else {
#                         input_769216033.style.display = "none"; // hide
#                         link_769216033.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_769216033 = $("a[id='769216033']");
#                 var cell_769216033 = link_769216033.parents("div.cell:first");
#                 if (cell_769216033.length == 0) {
#                     cell_769216033 = link_769216033.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_769216033 = cell_769216033.children("div.input");
#                 if (input_769216033.length == 0) {
#                     input_769216033 = cell_769216033.prev("div.nbinput");
#                 }
#                 input_769216033.hide();
#
#                 toggle_input_769216033 = function() {
#                     if (input_769216033.is(':hidden')) {
#                         input_769216033.slideDown();
#                         link_769216033[0].innerHTML = "Hide Input";
#                     } else {
#                         input_769216033.slideUp();
#                         link_769216033[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# The accuracy of the decoded estimate increases
# as the number of neurons increases.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(15, 3.5))

plt.subplot(1, 3, 1)
eval_points, activities = tuning_curves(A, sim)
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")

ax = plt.subplot(1, 3, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")

plt.subplot(1, 3, 3)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="337338567" href="javascript:toggle_input_337338567()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_337338567;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_337338567 = document.getElementById("337338567");
#                 var cell = link_337338567;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_337338567;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_337338567 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_337338567 = cell.previousElementSibling;
#                 }
#                 input_337338567.style.display = "none"; // hide
#
#                 toggle_input_337338567 = function() {
#                     if (input_337338567.style.display == "none") {
#                         input_337338567.style.display = ""; // show
#                         link_337338567.innerHTML = "Hide Input";
#                     } else {
#                         input_337338567.style.display = "none"; // hide
#                         link_337338567.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_337338567 = $("a[id='337338567']");
#                 var cell_337338567 = link_337338567.parents("div.cell:first");
#                 if (cell_337338567.length == 0) {
#                     cell_337338567 = link_337338567.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_337338567 = cell_337338567.children("div.input");
#                 if (input_337338567.length == 0) {
#                     input_337338567 = cell_337338567.prev("div.nbinput");
#                 }
#                 input_337338567.hide();
#
#                 toggle_input_337338567 = function() {
#                     if (input_337338567.is(':hidden')) {
#                         input_337338567.slideDown();
#                         link_337338567[0].innerHTML = "Hide Input";
#                     } else {
#                         input_337338567.slideUp();
#                         link_337338567[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Any smooth signal can be encoded and decoded.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="326433852" href="javascript:toggle_input_326433852()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_326433852;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_326433852 = document.getElementById("326433852");
#                 var cell = link_326433852;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_326433852;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_326433852 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_326433852 = cell.previousElementSibling;
#                 }
#                 input_326433852.style.display = "none"; // hide
#
#                 toggle_input_326433852 = function() {
#                     if (input_326433852.style.display == "none") {
#                         input_326433852.style.display = ""; // show
#                         link_326433852.innerHTML = "Hide Input";
#                     } else {
#                         input_326433852.style.display = "none"; // hide
#                         link_326433852.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_326433852 = $("a[id='326433852']");
#                 var cell_326433852 = link_326433852.parents("div.cell:first");
#                 if (cell_326433852.length == 0) {
#                     cell_326433852 = link_326433852.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_326433852 = cell_326433852.children("div.input");
#                 if (input_326433852.length == 0) {
#                     input_326433852 = cell_326433852.prev("div.nbinput");
#                 }
#                 input_326433852.hide();
#
#                 toggle_input_326433852 = function() {
#                     if (input_326433852.is(':hidden')) {
#                         input_326433852.slideDown();
#                         link_326433852[0].innerHTML = "Hide Input";
#                     } else {
#                         input_326433852.slideUp();
#                         link_326433852[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 2: Transformation
#
# Encoding and decoding allow us to encode signals over time,
# and decode transformations of those signals.
#
# In fact, we can decode arbitrary transformations of the input signal,
# not just the signal itself (as in the previous example).
#
# Let's decode the square of our white noise input.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input, )
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    Asquare = nengo.Node(size_in=1)
    nengo.Connection(input, A)
    nengo.Connection(A, Asquare, function=np.square)
    A_spikes = nengo.Probe(A.neurons)
    Asquare_probe = nengo.Probe(Asquare, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(
    sim.trange(),
    sim.data[input_probe],
    label="Input signal")
plt.plot(
    sim.trange(),
    sim.data[Asquare_probe],
    label="Decoded esimate")
plt.plot(
    sim.trange(),
    np.square(sim.data[input_probe]),
    label="Input signal squared")
plt.legend(loc="best", fontsize='medium')
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes])
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1902754086" href="javascript:toggle_input_1902754086()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1902754086;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1902754086 = document.getElementById("1902754086");
#                 var cell = link_1902754086;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1902754086;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1902754086 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1902754086 = cell.previousElementSibling;
#                 }
#                 input_1902754086.style.display = "none"; // hide
#
#                 toggle_input_1902754086 = function() {
#                     if (input_1902754086.style.display == "none") {
#                         input_1902754086.style.display = ""; // show
#                         link_1902754086.innerHTML = "Hide Input";
#                     } else {
#                         input_1902754086.style.display = "none"; // hide
#                         link_1902754086.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1902754086 = $("a[id='1902754086']");
#                 var cell_1902754086 = link_1902754086.parents("div.cell:first");
#                 if (cell_1902754086.length == 0) {
#                     cell_1902754086 = link_1902754086.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1902754086 = cell_1902754086.children("div.input");
#                 if (input_1902754086.length == 0) {
#                     input_1902754086 = cell_1902754086.prev("div.nbinput");
#                 }
#                 input_1902754086.hide();
#
#                 toggle_input_1902754086 = function() {
#                     if (input_1902754086.is(':hidden')) {
#                         input_1902754086.slideDown();
#                         link_1902754086[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1902754086.slideUp();
#                         link_1902754086[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Notice that the spike trains are exactly the same.
# The only difference is how we're interpreting those spikes.
# We told Nengo to compute a new set of decoders
# that estimate the function $x^2$.
#
# In general, the transformation principle
# determines how we can decode spike trains
# to compute linear and nonlinear transformations of signals
# encoded in a population of neurons.
# We can then project those transformed signals
# into another population, and repeat the process.
# Essentially, this provides a means of
# computing the neural connection weights
# to compute an arbitrary function between populations.
#
# Suppose we are representing a sine wave.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: np.sin(np.pi * t))
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="794601591" href="javascript:toggle_input_794601591()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_794601591;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_794601591 = document.getElementById("794601591");
#                 var cell = link_794601591;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_794601591;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_794601591 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_794601591 = cell.previousElementSibling;
#                 }
#                 input_794601591.style.display = "none"; // hide
#
#                 toggle_input_794601591 = function() {
#                     if (input_794601591.style.display == "none") {
#                         input_794601591.style.display = ""; // show
#                         link_794601591.innerHTML = "Hide Input";
#                     } else {
#                         input_794601591.style.display = "none"; // hide
#                         link_794601591.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_794601591 = $("a[id='794601591']");
#                 var cell_794601591 = link_794601591.parents("div.cell:first");
#                 if (cell_794601591.length == 0) {
#                     cell_794601591 = link_794601591.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_794601591 = cell_794601591.children("div.input");
#                 if (input_794601591.length == 0) {
#                     input_794601591 = cell_794601591.prev("div.nbinput");
#                 }
#                 input_794601591.hide();
#
#                 toggle_input_794601591 = function() {
#                     if (input_794601591.is(':hidden')) {
#                         input_794601591.slideDown();
#                         link_794601591[0].innerHTML = "Hide Input";
#                     } else {
#                         input_794601591.slideUp();
#                         link_794601591[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Linear transformations of that signal
# involve solving for the usual decoders,
# and scaling those decoding weights.
# Let us flip this sine wave upside down
# as it is transmitted between two populations
# (i.e. population A and population -A).

# %%
with model:
    minusA = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(A, minusA, function=lambda x: -x)
    minusA_spikes = nengo.Probe(minusA.neurons)
    minusA_probe = nengo.Probe(minusA, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 5))
plt.subplot(2, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(2, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.title("-A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(2, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(2, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="805945471" href="javascript:toggle_input_805945471()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_805945471;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_805945471 = document.getElementById("805945471");
#                 var cell = link_805945471;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_805945471;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_805945471 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_805945471 = cell.previousElementSibling;
#                 }
#                 input_805945471.style.display = "none"; // hide
#
#                 toggle_input_805945471 = function() {
#                     if (input_805945471.style.display == "none") {
#                         input_805945471.style.display = ""; // show
#                         link_805945471.innerHTML = "Hide Input";
#                     } else {
#                         input_805945471.style.display = "none"; // hide
#                         link_805945471.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_805945471 = $("a[id='805945471']");
#                 var cell_805945471 = link_805945471.parents("div.cell:first");
#                 if (cell_805945471.length == 0) {
#                     cell_805945471 = link_805945471.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_805945471 = cell_805945471.children("div.input");
#                 if (input_805945471.length == 0) {
#                     input_805945471 = cell_805945471.prev("div.nbinput");
#                 }
#                 input_805945471.hide();
#
#                 toggle_input_805945471 = function() {
#                     if (input_805945471.is(':hidden')) {
#                         input_805945471.slideDown();
#                         link_805945471[0].innerHTML = "Hide Input";
#                     } else {
#                         input_805945471.slideUp();
#                         link_805945471[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Nonlinear transformations involve
# solving for a new set of decoding weights.
# Let us add a third population connected
# to the second one and use it to compute $(-A)^2$.

# %%
with model:
    A_squared = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(minusA, A_squared, function=lambda x: x ** 2)
    A_squared_spikes = nengo.Probe(A_squared.neurons)
    A_squared_probe = nengo.Probe(A_squared, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 6.5))
plt.subplot(3, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.axhline(0, color='k')
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.axhline(0, color='k')
plt.title("-A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 5)
plt.plot(sim.trange(), sim.data[A_squared_probe])
plt.axhline(0, color='k')
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(3, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 6)
rasterplot(sim.trange(), sim.data[A_squared_spikes], ax)
plt.xlim(0, 2)
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1166898180" href="javascript:toggle_input_1166898180()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1166898180;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1166898180 = document.getElementById("1166898180");
#                 var cell = link_1166898180;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1166898180;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1166898180 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1166898180 = cell.previousElementSibling;
#                 }
#                 input_1166898180.style.display = "none"; // hide
#
#                 toggle_input_1166898180 = function() {
#                     if (input_1166898180.style.display == "none") {
#                         input_1166898180.style.display = ""; // show
#                         link_1166898180.innerHTML = "Hide Input";
#                     } else {
#                         input_1166898180.style.display = "none"; // hide
#                         link_1166898180.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1166898180 = $("a[id='1166898180']");
#                 var cell_1166898180 = link_1166898180.parents("div.cell:first");
#                 if (cell_1166898180.length == 0) {
#                     cell_1166898180 = link_1166898180.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1166898180 = cell_1166898180.children("div.input");
#                 if (input_1166898180.length == 0) {
#                     input_1166898180 = cell_1166898180.prev("div.nbinput");
#                 }
#                 input_1166898180.hide();
#
#                 toggle_input_1166898180 = function() {
#                     if (input_1166898180.is(':hidden')) {
#                         input_1166898180.slideDown();
#                         link_1166898180[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1166898180.slideUp();
#                         link_1166898180[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 3: Dynamics
#
# So far, we have been considering the values
# represented by ensembles as generic "signals."
# However, if we think of them instead
# as state variables in a dynamical system,
# then we can apply the methods of control theory
# or dynamic systems theory to brain models.
# Nengo automatically translates from standard dynamical systems descriptions
# to descriptions consistent with neural dynamics.
#
# In order to get interesting dynamics,
# we can connect populations recurrently (i.e., to themselves).
#
# Below is a simple harmonic oscillator
# implemented using this third principle.
# It needs is a bit of input to get it started.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: [1, 0] if t < 0.1 else [0, 0])
    oscillator = nengo.Ensemble(200, dimensions=2)
    nengo.Connection(input, oscillator)
    nengo.Connection(
        oscillator, oscillator, transform=[[1, 1], [-1, 1]], synapse=0.1)
    oscillator_probe = nengo.Probe(oscillator, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(3)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[oscillator_probe])
plt.ylim(-1.2, 1.2)
plt.xlabel('Time (s)')

plt.subplot(1, 2, 2)
plt.plot(sim.data[oscillator_probe][:, 0], sim.data[oscillator_probe][:, 1])
plt.grid()
plt.axis([-1.2, 1.2, -1.2, 1.2])
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
hide_input()
# Out:
#         <a id="70214427" href="javascript:toggle_input_70214427()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_70214427;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_70214427 = document.getElementById("70214427");
#                 var cell = link_70214427;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_70214427;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_70214427 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_70214427 = cell.previousElementSibling;
#                 }
#                 input_70214427.style.display = "none"; // hide
#
#                 toggle_input_70214427 = function() {
#                     if (input_70214427.style.display == "none") {
#                         input_70214427.style.display = ""; // show
#                         link_70214427.innerHTML = "Hide Input";
#                     } else {
#                         input_70214427.style.display = "none"; // hide
#                         link_70214427.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_70214427 = $("a[id='70214427']");
#                 var cell_70214427 = link_70214427.parents("div.cell:first");
#                 if (cell_70214427.length == 0) {
#                     cell_70214427 = link_70214427.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_70214427 = cell_70214427.children("div.input");
#                 if (input_70214427.length == 0) {
#                     input_70214427 = cell_70214427.prev("div.nbinput");
#                 }
#                 input_70214427.hide();
#
#                 toggle_input_70214427 = function() {
#                     if (input_70214427.is(':hidden')) {
#                         input_70214427.slideDown();
#                         link_70214427[0].innerHTML = "Hide Input";
#                     } else {
#                         input_70214427.slideUp();
#                         link_70214427[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>
