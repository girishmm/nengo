# %% [markdown]
# # NEF summary
#
# The Neural Engineering Framework (NEF)
# is one set of theoretical methods that are used in
# Nengo for constructing neural models.
# The NEF is based on [Eliasmith & Anderson's (2003) book](
# https://mitpress.mit.edu/books/neural-engineering) from MIT Press.
# This notebook introduces the three main principles
# discussed in that book and implemented in Nengo.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

import nengo
from nengo.dists import Uniform
from nengo.processes import WhiteSignal
from nengo.utils.ensemble import tuning_curves
from nengo.utils.ipython import hide_input
from nengo.utils.matplotlib import rasterplot


def aligned(n_neurons, radius=0.9):
    intercepts = np.linspace(-radius, radius, n_neurons)
    encoders = np.tile([[1], [-1]], (n_neurons // 2, 1))
    intercepts *= encoders[:, 0]
    return intercepts, encoders


hide_input()
# Out:
#         <a id="1337231682" href="javascript:toggle_input_1337231682()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1337231682;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1337231682 = document.getElementById("1337231682");
#                 var cell = link_1337231682;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1337231682;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1337231682 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1337231682 = cell.previousElementSibling;
#                 }
#                 input_1337231682.style.display = "none"; // hide
#
#                 toggle_input_1337231682 = function() {
#                     if (input_1337231682.style.display == "none") {
#                         input_1337231682.style.display = ""; // show
#                         link_1337231682.innerHTML = "Hide Input";
#                     } else {
#                         input_1337231682.style.display = "none"; // hide
#                         link_1337231682.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1337231682 = $("a[id='1337231682']");
#                 var cell_1337231682 = link_1337231682.parents("div.cell:first");
#                 if (cell_1337231682.length == 0) {
#                     cell_1337231682 = link_1337231682.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1337231682 = cell_1337231682.children("div.input");
#                 if (input_1337231682.length == 0) {
#                     input_1337231682 = cell_1337231682.prev("div.nbinput");
#                 }
#                 input_1337231682.hide();
#
#                 toggle_input_1337231682 = function() {
#                     if (input_1337231682.is(':hidden')) {
#                         input_1337231682.slideDown();
#                         link_1337231682[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1337231682.slideUp();
#                         link_1337231682[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 1: Representation
#
# ### Encoding
#
# Neural populations represent time-varying signals
# through their spiking responses.
# A signal is a vector of real numbers of arbitrary length.
# This example is a 1D signal going from -1 to 1 in 1 second.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1.0)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], lw=2)
plt.title("Input signal")
plt.xlabel("Time (s)")
plt.xlim(0, 1);
hide_input()
# Out:
#         <a id="1561955407" href="javascript:toggle_input_1561955407()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1561955407;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1561955407 = document.getElementById("1561955407");
#                 var cell = link_1561955407;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1561955407;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1561955407 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1561955407 = cell.previousElementSibling;
#                 }
#                 input_1561955407.style.display = "none"; // hide
#
#                 toggle_input_1561955407 = function() {
#                     if (input_1561955407.style.display == "none") {
#                         input_1561955407.style.display = ""; // show
#                         link_1561955407.innerHTML = "Hide Input";
#                     } else {
#                         input_1561955407.style.display = "none"; // hide
#                         link_1561955407.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1561955407 = $("a[id='1561955407']");
#                 var cell_1561955407 = link_1561955407.parents("div.cell:first");
#                 if (cell_1561955407.length == 0) {
#                     cell_1561955407 = link_1561955407.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1561955407 = cell_1561955407.children("div.input");
#                 if (input_1561955407.length == 0) {
#                     input_1561955407 = cell_1561955407.prev("div.nbinput");
#                 }
#                 input_1561955407.hide();
#
#                 toggle_input_1561955407 = function() {
#                     if (input_1561955407.is(':hidden')) {
#                         input_1561955407.slideDown();
#                         link_1561955407[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1561955407.slideUp();
#                         link_1561955407[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# These signals drive neural populations
# based on each neuron's *tuning curve*
# (which is similar to the current-frequency curve,
# if you're familiar with that).
#
# The tuning curve describes how much
# a particular neuron will fire as a function of the input signal.

# %%
intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
with model:
    A = nengo.Ensemble(
        8,
        dimensions=1,
        intercepts=intercepts,
        max_rates=Uniform(80, 100),
        encoders=encoders)

# %%
with nengo.Simulator(model) as sim:
    eval_points, activities = tuning_curves(A, sim)

plt.figure()
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)");
hide_input()
# Out:
#         <a id="1579283149" href="javascript:toggle_input_1579283149()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1579283149;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1579283149 = document.getElementById("1579283149");
#                 var cell = link_1579283149;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1579283149;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1579283149 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1579283149 = cell.previousElementSibling;
#                 }
#                 input_1579283149.style.display = "none"; // hide
#
#                 toggle_input_1579283149 = function() {
#                     if (input_1579283149.style.display == "none") {
#                         input_1579283149.style.display = ""; // show
#                         link_1579283149.innerHTML = "Hide Input";
#                     } else {
#                         input_1579283149.style.display = "none"; // hide
#                         link_1579283149.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1579283149 = $("a[id='1579283149']");
#                 var cell_1579283149 = link_1579283149.parents("div.cell:first");
#                 if (cell_1579283149.length == 0) {
#                     cell_1579283149 = link_1579283149.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1579283149 = cell_1579283149.children("div.input");
#                 if (input_1579283149.length == 0) {
#                     input_1579283149 = cell_1579283149.prev("div.nbinput");
#                 }
#                 input_1579283149.hide();
#
#                 toggle_input_1579283149 = function() {
#                     if (input_1579283149.is(':hidden')) {
#                         input_1579283149.slideDown();
#                         link_1579283149[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1579283149.slideUp();
#                         link_1579283149[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# We can drive these neurons with our input signal
# and observe their spiking activity over time.

# %%
with model:
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
ax = plt.subplot(1, 1, 1)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
ax.set_xlim(0, 1)
ax.set_ylabel('Neuron')
ax.set_xlabel('Time (s)');
hide_input()
# Out:
#         <a id="1637862077" href="javascript:toggle_input_1637862077()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1637862077;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1637862077 = document.getElementById("1637862077");
#                 var cell = link_1637862077;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1637862077;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1637862077 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1637862077 = cell.previousElementSibling;
#                 }
#                 input_1637862077.style.display = "none"; // hide
#
#                 toggle_input_1637862077 = function() {
#                     if (input_1637862077.style.display == "none") {
#                         input_1637862077.style.display = ""; // show
#                         link_1637862077.innerHTML = "Hide Input";
#                     } else {
#                         input_1637862077.style.display = "none"; // hide
#                         link_1637862077.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1637862077 = $("a[id='1637862077']");
#                 var cell_1637862077 = link_1637862077.parents("div.cell:first");
#                 if (cell_1637862077.length == 0) {
#                     cell_1637862077 = link_1637862077.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1637862077 = cell_1637862077.children("div.input");
#                 if (input_1637862077.length == 0) {
#                     input_1637862077 = cell_1637862077.prev("div.nbinput");
#                 }
#                 input_1637862077.hide();
#
#                 toggle_input_1637862077 = function() {
#                     if (input_1637862077.is(':hidden')) {
#                         input_1637862077.slideDown();
#                         link_1637862077[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1637862077.slideUp();
#                         link_1637862077[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ### Decoding
#
# We can estimate the input signal
# originally encoded by decoding the pattern of spikes.
# To do this, we first filter the spike train
# with a temporal filter that accounts for
# postsynaptic current (PSC) activity.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
    A = nengo.Ensemble(8, dimensions=1,
                       intercepts=intercepts,
                       max_rates=Uniform(80, 100),
                       encoders=encoders)
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

scale = 180
plt.figure()
for i in range(A.n_neurons):
    plt.plot(sim.trange(), sim.data[A_spikes][:, i] - i * scale)
plt.xlim(0, 1)
plt.ylim(scale * (-A.n_neurons + 1), scale)
plt.ylabel("Neuron")
plt.yticks(
    np.arange(scale / 1.8, (-A.n_neurons + 1) * scale, -scale),
    np.arange(A.n_neurons))
hide_input()
# Out:
#         <a id="259915863" href="javascript:toggle_input_259915863()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_259915863;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_259915863 = document.getElementById("259915863");
#                 var cell = link_259915863;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_259915863;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_259915863 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_259915863 = cell.previousElementSibling;
#                 }
#                 input_259915863.style.display = "none"; // hide
#
#                 toggle_input_259915863 = function() {
#                     if (input_259915863.style.display == "none") {
#                         input_259915863.style.display = ""; // show
#                         link_259915863.innerHTML = "Hide Input";
#                     } else {
#                         input_259915863.style.display = "none"; // hide
#                         link_259915863.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_259915863 = $("a[id='259915863']");
#                 var cell_259915863 = link_259915863.parents("div.cell:first");
#                 if (cell_259915863.length == 0) {
#                     cell_259915863 = link_259915863.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_259915863 = cell_259915863.children("div.input");
#                 if (input_259915863.length == 0) {
#                     input_259915863 = cell_259915863.prev("div.nbinput");
#                 }
#                 input_259915863.hide();
#
#                 toggle_input_259915863 = function() {
#                     if (input_259915863.is(':hidden')) {
#                         input_259915863.slideDown();
#                         link_259915863[0].innerHTML = "Hide Input";
#                     } else {
#                         input_259915863.slideUp();
#                         link_259915863[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Then we mulitply those filtered spike trains
# with decoding weights and sum them together
# to give an estimate of the input based on the spikes.
#
# The decoding weights are determined
# by minimizing the squared difference
# between the decoded estimate and the actual input signal.

# %%
with model:
    A_probe = nengo.Probe(A, synapse=0.01)  # 10ms PSC filter

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded estimate")
plt.legend(loc="best")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="2091973651" href="javascript:toggle_input_2091973651()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_2091973651;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_2091973651 = document.getElementById("2091973651");
#                 var cell = link_2091973651;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_2091973651;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_2091973651 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_2091973651 = cell.previousElementSibling;
#                 }
#                 input_2091973651.style.display = "none"; // hide
#
#                 toggle_input_2091973651 = function() {
#                     if (input_2091973651.style.display == "none") {
#                         input_2091973651.style.display = ""; // show
#                         link_2091973651.innerHTML = "Hide Input";
#                     } else {
#                         input_2091973651.style.display = "none"; // hide
#                         link_2091973651.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_2091973651 = $("a[id='2091973651']");
#                 var cell_2091973651 = link_2091973651.parents("div.cell:first");
#                 if (cell_2091973651.length == 0) {
#                     cell_2091973651 = link_2091973651.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_2091973651 = cell_2091973651.children("div.input");
#                 if (input_2091973651.length == 0) {
#                     input_2091973651 = cell_2091973651.prev("div.nbinput");
#                 }
#                 input_2091973651.hide();
#
#                 toggle_input_2091973651 = function() {
#                     if (input_2091973651.is(':hidden')) {
#                         input_2091973651.slideDown();
#                         link_2091973651[0].innerHTML = "Hide Input";
#                     } else {
#                         input_2091973651.slideUp();
#                         link_2091973651[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# The accuracy of the decoded estimate increases
# as the number of neurons increases.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(15, 3.5))

plt.subplot(1, 3, 1)
eval_points, activities = tuning_curves(A, sim)
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")

ax = plt.subplot(1, 3, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")

plt.subplot(1, 3, 3)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="1540203837" href="javascript:toggle_input_1540203837()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1540203837;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1540203837 = document.getElementById("1540203837");
#                 var cell = link_1540203837;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1540203837;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1540203837 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1540203837 = cell.previousElementSibling;
#                 }
#                 input_1540203837.style.display = "none"; // hide
#
#                 toggle_input_1540203837 = function() {
#                     if (input_1540203837.style.display == "none") {
#                         input_1540203837.style.display = ""; // show
#                         link_1540203837.innerHTML = "Hide Input";
#                     } else {
#                         input_1540203837.style.display = "none"; // hide
#                         link_1540203837.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1540203837 = $("a[id='1540203837']");
#                 var cell_1540203837 = link_1540203837.parents("div.cell:first");
#                 if (cell_1540203837.length == 0) {
#                     cell_1540203837 = link_1540203837.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1540203837 = cell_1540203837.children("div.input");
#                 if (input_1540203837.length == 0) {
#                     input_1540203837 = cell_1540203837.prev("div.nbinput");
#                 }
#                 input_1540203837.hide();
#
#                 toggle_input_1540203837 = function() {
#                     if (input_1540203837.is(':hidden')) {
#                         input_1540203837.slideDown();
#                         link_1540203837[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1540203837.slideUp();
#                         link_1540203837[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Any smooth signal can be encoded and decoded.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1113360987" href="javascript:toggle_input_1113360987()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1113360987;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1113360987 = document.getElementById("1113360987");
#                 var cell = link_1113360987;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1113360987;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1113360987 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1113360987 = cell.previousElementSibling;
#                 }
#                 input_1113360987.style.display = "none"; // hide
#
#                 toggle_input_1113360987 = function() {
#                     if (input_1113360987.style.display == "none") {
#                         input_1113360987.style.display = ""; // show
#                         link_1113360987.innerHTML = "Hide Input";
#                     } else {
#                         input_1113360987.style.display = "none"; // hide
#                         link_1113360987.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1113360987 = $("a[id='1113360987']");
#                 var cell_1113360987 = link_1113360987.parents("div.cell:first");
#                 if (cell_1113360987.length == 0) {
#                     cell_1113360987 = link_1113360987.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1113360987 = cell_1113360987.children("div.input");
#                 if (input_1113360987.length == 0) {
#                     input_1113360987 = cell_1113360987.prev("div.nbinput");
#                 }
#                 input_1113360987.hide();
#
#                 toggle_input_1113360987 = function() {
#                     if (input_1113360987.is(':hidden')) {
#                         input_1113360987.slideDown();
#                         link_1113360987[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1113360987.slideUp();
#                         link_1113360987[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 2: Transformation
#
# Encoding and decoding allow us to encode signals over time,
# and decode transformations of those signals.
#
# In fact, we can decode arbitrary transformations of the input signal,
# not just the signal itself (as in the previous example).
#
# Let's decode the square of our white noise input.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input, )
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    Asquare = nengo.Node(size_in=1)
    nengo.Connection(input, A)
    nengo.Connection(A, Asquare, function=np.square)
    A_spikes = nengo.Probe(A.neurons)
    Asquare_probe = nengo.Probe(Asquare, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(
    sim.trange(),
    sim.data[input_probe],
    label="Input signal")
plt.plot(
    sim.trange(),
    sim.data[Asquare_probe],
    label="Decoded esimate")
plt.plot(
    sim.trange(),
    np.square(sim.data[input_probe]),
    label="Input signal squared")
plt.legend(loc="best", fontsize='medium')
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes])
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="82738620" href="javascript:toggle_input_82738620()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_82738620;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_82738620 = document.getElementById("82738620");
#                 var cell = link_82738620;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_82738620;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_82738620 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_82738620 = cell.previousElementSibling;
#                 }
#                 input_82738620.style.display = "none"; // hide
#
#                 toggle_input_82738620 = function() {
#                     if (input_82738620.style.display == "none") {
#                         input_82738620.style.display = ""; // show
#                         link_82738620.innerHTML = "Hide Input";
#                     } else {
#                         input_82738620.style.display = "none"; // hide
#                         link_82738620.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_82738620 = $("a[id='82738620']");
#                 var cell_82738620 = link_82738620.parents("div.cell:first");
#                 if (cell_82738620.length == 0) {
#                     cell_82738620 = link_82738620.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_82738620 = cell_82738620.children("div.input");
#                 if (input_82738620.length == 0) {
#                     input_82738620 = cell_82738620.prev("div.nbinput");
#                 }
#                 input_82738620.hide();
#
#                 toggle_input_82738620 = function() {
#                     if (input_82738620.is(':hidden')) {
#                         input_82738620.slideDown();
#                         link_82738620[0].innerHTML = "Hide Input";
#                     } else {
#                         input_82738620.slideUp();
#                         link_82738620[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Notice that the spike trains are exactly the same.
# The only difference is how we're interpreting those spikes.
# We told Nengo to compute a new set of decoders
# that estimate the function $x^2$.
#
# In general, the transformation principle
# determines how we can decode spike trains
# to compute linear and nonlinear transformations of signals
# encoded in a population of neurons.
# We can then project those transformed signals
# into another population, and repeat the process.
# Essentially, this provides a means of
# computing the neural connection weights
# to compute an arbitrary function between populations.
#
# Suppose we are representing a sine wave.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: np.sin(np.pi * t))
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1680483151" href="javascript:toggle_input_1680483151()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1680483151;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1680483151 = document.getElementById("1680483151");
#                 var cell = link_1680483151;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1680483151;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1680483151 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1680483151 = cell.previousElementSibling;
#                 }
#                 input_1680483151.style.display = "none"; // hide
#
#                 toggle_input_1680483151 = function() {
#                     if (input_1680483151.style.display == "none") {
#                         input_1680483151.style.display = ""; // show
#                         link_1680483151.innerHTML = "Hide Input";
#                     } else {
#                         input_1680483151.style.display = "none"; // hide
#                         link_1680483151.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1680483151 = $("a[id='1680483151']");
#                 var cell_1680483151 = link_1680483151.parents("div.cell:first");
#                 if (cell_1680483151.length == 0) {
#                     cell_1680483151 = link_1680483151.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1680483151 = cell_1680483151.children("div.input");
#                 if (input_1680483151.length == 0) {
#                     input_1680483151 = cell_1680483151.prev("div.nbinput");
#                 }
#                 input_1680483151.hide();
#
#                 toggle_input_1680483151 = function() {
#                     if (input_1680483151.is(':hidden')) {
#                         input_1680483151.slideDown();
#                         link_1680483151[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1680483151.slideUp();
#                         link_1680483151[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Linear transformations of that signal
# involve solving for the usual decoders,
# and scaling those decoding weights.
# Let us flip this sine wave upside down
# as it is transmitted between two populations
# (i.e. population A and population -A).

# %%
with model:
    minusA = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(A, minusA, function=lambda x: -x)
    minusA_spikes = nengo.Probe(minusA.neurons)
    minusA_probe = nengo.Probe(minusA, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 5))
plt.subplot(2, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(2, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.title("-A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(2, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(2, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="584671823" href="javascript:toggle_input_584671823()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_584671823;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_584671823 = document.getElementById("584671823");
#                 var cell = link_584671823;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_584671823;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_584671823 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_584671823 = cell.previousElementSibling;
#                 }
#                 input_584671823.style.display = "none"; // hide
#
#                 toggle_input_584671823 = function() {
#                     if (input_584671823.style.display == "none") {
#                         input_584671823.style.display = ""; // show
#                         link_584671823.innerHTML = "Hide Input";
#                     } else {
#                         input_584671823.style.display = "none"; // hide
#                         link_584671823.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_584671823 = $("a[id='584671823']");
#                 var cell_584671823 = link_584671823.parents("div.cell:first");
#                 if (cell_584671823.length == 0) {
#                     cell_584671823 = link_584671823.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_584671823 = cell_584671823.children("div.input");
#                 if (input_584671823.length == 0) {
#                     input_584671823 = cell_584671823.prev("div.nbinput");
#                 }
#                 input_584671823.hide();
#
#                 toggle_input_584671823 = function() {
#                     if (input_584671823.is(':hidden')) {
#                         input_584671823.slideDown();
#                         link_584671823[0].innerHTML = "Hide Input";
#                     } else {
#                         input_584671823.slideUp();
#                         link_584671823[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Nonlinear transformations involve
# solving for a new set of decoding weights.
# Let us add a third population connected
# to the second one and use it to compute $(-A)^2$.

# %%
with model:
    A_squared = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(minusA, A_squared, function=lambda x: x ** 2)
    A_squared_spikes = nengo.Probe(A_squared.neurons)
    A_squared_probe = nengo.Probe(A_squared, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 6.5))
plt.subplot(3, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.axhline(0, color='k')
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.axhline(0, color='k')
plt.title("-A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 5)
plt.plot(sim.trange(), sim.data[A_squared_probe])
plt.axhline(0, color='k')
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(3, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 6)
rasterplot(sim.trange(), sim.data[A_squared_spikes], ax)
plt.xlim(0, 2)
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1899122966" href="javascript:toggle_input_1899122966()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1899122966;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1899122966 = document.getElementById("1899122966");
#                 var cell = link_1899122966;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1899122966;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1899122966 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1899122966 = cell.previousElementSibling;
#                 }
#                 input_1899122966.style.display = "none"; // hide
#
#                 toggle_input_1899122966 = function() {
#                     if (input_1899122966.style.display == "none") {
#                         input_1899122966.style.display = ""; // show
#                         link_1899122966.innerHTML = "Hide Input";
#                     } else {
#                         input_1899122966.style.display = "none"; // hide
#                         link_1899122966.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1899122966 = $("a[id='1899122966']");
#                 var cell_1899122966 = link_1899122966.parents("div.cell:first");
#                 if (cell_1899122966.length == 0) {
#                     cell_1899122966 = link_1899122966.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1899122966 = cell_1899122966.children("div.input");
#                 if (input_1899122966.length == 0) {
#                     input_1899122966 = cell_1899122966.prev("div.nbinput");
#                 }
#                 input_1899122966.hide();
#
#                 toggle_input_1899122966 = function() {
#                     if (input_1899122966.is(':hidden')) {
#                         input_1899122966.slideDown();
#                         link_1899122966[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1899122966.slideUp();
#                         link_1899122966[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 3: Dynamics
#
# So far, we have been considering the values
# represented by ensembles as generic "signals."
# However, if we think of them instead
# as state variables in a dynamical system,
# then we can apply the methods of control theory
# or dynamic systems theory to brain models.
# Nengo automatically translates from standard dynamical systems descriptions
# to descriptions consistent with neural dynamics.
#
# In order to get interesting dynamics,
# we can connect populations recurrently (i.e., to themselves).
#
# Below is a simple harmonic oscillator
# implemented using this third principle.
# It needs is a bit of input to get it started.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: [1, 0] if t < 0.1 else [0, 0])
    oscillator = nengo.Ensemble(200, dimensions=2)
    nengo.Connection(input, oscillator)
    nengo.Connection(
        oscillator, oscillator, transform=[[1, 1], [-1, 1]], synapse=0.1)
    oscillator_probe = nengo.Probe(oscillator, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(3)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[oscillator_probe])
plt.ylim(-1.2, 1.2)
plt.xlabel('Time (s)')

plt.subplot(1, 2, 2)
plt.plot(sim.data[oscillator_probe][:, 0], sim.data[oscillator_probe][:, 1])
plt.grid()
plt.axis([-1.2, 1.2, -1.2, 1.2])
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
hide_input()
# Out:
#         <a id="1019278990" href="javascript:toggle_input_1019278990()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1019278990;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1019278990 = document.getElementById("1019278990");
#                 var cell = link_1019278990;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1019278990;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1019278990 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1019278990 = cell.previousElementSibling;
#                 }
#                 input_1019278990.style.display = "none"; // hide
#
#                 toggle_input_1019278990 = function() {
#                     if (input_1019278990.style.display == "none") {
#                         input_1019278990.style.display = ""; // show
#                         link_1019278990.innerHTML = "Hide Input";
#                     } else {
#                         input_1019278990.style.display = "none"; // hide
#                         link_1019278990.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1019278990 = $("a[id='1019278990']");
#                 var cell_1019278990 = link_1019278990.parents("div.cell:first");
#                 if (cell_1019278990.length == 0) {
#                     cell_1019278990 = link_1019278990.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1019278990 = cell_1019278990.children("div.input");
#                 if (input_1019278990.length == 0) {
#                     input_1019278990 = cell_1019278990.prev("div.nbinput");
#                 }
#                 input_1019278990.hide();
#
#                 toggle_input_1019278990 = function() {
#                     if (input_1019278990.is(':hidden')) {
#                         input_1019278990.slideDown();
#                         link_1019278990[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1019278990.slideUp();
#                         link_1019278990[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>
